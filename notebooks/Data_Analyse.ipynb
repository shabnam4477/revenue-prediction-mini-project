# %%
del OB_df
OB_df = None

# %%
import pandas as pd

OB_df = pd.read_csv("raw_open_banking_data.csv")
OB_df.head()
# Out:
#     transaction_id company_id     transaction_date  transaction_amount  \
# 0  txn_company_1_1  company_1  2024-01-01 00:00:00              2000.0
# 1  txn_company_1_2  company_1  2024-01-01 01:00:00                 NaN
# 2  txn_company_1_3  company_1  2024-01-01 02:00:00               -50.0
# 3  txn_company_1_4  company_1  2024-01-01 03:00:00               300.0
# 4  txn_company_1_5  company_1  2024-01-01 04:00:00              2000.0
#
#             transaction_description  customer_id payment_method
# 0  Capital investment from investor          152     debit_card
# 1                  Refund processed          193    credit_card
# 2          Office supplies purchase          115    credit_card
# 3            Educational toy income          172    credit_card
# 4              Rebate from supplier          161    credit_card

# %% [markdown]
# # Explore the data

# %%
OB_df.shape
# Out:
# (604, 7)

# %%
OB_df.columns
# Out:
# Index(['transaction_id', 'company_id', 'transaction_date',
#        'transaction_amount', 'transaction_description', 'customer_id',
#        'payment_method'],
#       dtype='object')

# %%
OB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604 entries, 0 to 603
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           604 non-null    object
#  1   company_id               604 non-null    object
#  2   transaction_date         604 non-null    object
#  3   transaction_amount       574 non-null    float64
#  4   transaction_description  604 non-null    object
#  5   customer_id              604 non-null    int64
#  6   payment_method           604 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 33.2+ KB

# %%
OB_df.describe()
# Out:
#        transaction_amount  customer_id
# count        5.740000e+02   604.000000
# mean         9.796254e+03   151.266556
# std          1.794268e+05    30.115424
# min         -2.000000e+06   101.000000
# 25%         -1.375000e+02   123.000000
# 50%          3.000000e+02   152.500000
# 75%          2.000000e+03   179.000000
# max          2.000000e+06   200.000000

# %% [markdown]
# # Observation
# Out of 7 columns, we have 2 numerical columns(one of them is customer_id which is not useful in calculation) and 5 categorical columns

# %% [markdown]
# # Data visualisation

# %%
# histogram to understand the distribution
import warnings
from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")
for i in OB_df.select_dtypes(include="number").columns:
    sns.histplot(data=OB_df, x=i)
    plt.show()

# %%
OB_df[OB_df["transaction_amount"] < -2000]
# Out:
#        transaction_id company_id     transaction_date  transaction_amount  \
# 29   txn_company_1_30  company_1  2024-01-02 05:00:00             -3375.0
# 185  txn_company_3_29  company_3  2024-01-02 04:00:00             -3375.0
# 368   txn_company_4_2  company_4  2024-01-01 01:00:00             -3375.0
# 529   txn_company_5_5  company_5  2024-01-01 04:00:00             -3375.0
#
#     transaction_description  customer_id payment_method
# 29        Marketing expense          149         paypal
# 185     Operational expense          193    credit_card
# 368     Operational expense          118     debit_card
# 529        Refund processed          152         paypal

# %% [markdown]
# # Feature Engineeering

# %% [markdown]
# ## Categerical data

# %% [markdown]
# ### Check for high and low cardinality

# %%
df_cat = OB_df.select_dtypes(include=["object"])
df_cat.nunique().sort_values()
# Out:
# payment_method               3
# company_id                   5
# transaction_description     47
# transaction_date           199
# transaction_id             575
# dtype: int64

# %% [markdown]
# ## drop the categorical columns with high cardinality

# %%
OB_df.drop(columns=["transaction_date", "transaction_id"], inplace=True)

# %%
## Duplicate data

# %%
OB_df.duplicated().sum()
# Out:
# 32

# %%
OB_df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Deal with missing values

# %%
OB_df.isna().sum()
# Out:
# company_id                  0
# transaction_amount         29
# transaction_description     0
# customer_id                 0
# payment_method              0
# dtype: int64

# %%
OB_df[OB_df["transaction_amount"].isnull()].groupby("company_id").size()
# Out:
# company_id
# company_1     5
# company_2     2
# company_3    10
# company_4     9
# company_5     4
# dtype: int64

# %% [markdown]
# # Observation
#
# Out of 604 samples, 30 of them are null for the transaction_amount, which is approximately the 5% of the data.
# Considering that our problem is regression and transaction_amount is our target column, what is the best way to fill the null values?
# - drop the null column
#   impossible, because the transaction_amount is our target column
# - drop the sample with null values
#   considering our dataset size is limited, we dont want to loose the data
# - fill with mean, median
#   we have outlier in our dataset
# - fill with random value
# - Impute the missing value using KNN
#    imputing with KNN Imputer, causes data leakage if the data has not been splitted before imputing
# - Analyse the data and research more then choose the proper method
#   Target variable is not advised to be imputed, this is because they control how the learning algorithm learns
#   5% is not a high percentage so we decide to remove the samples with missing values
#   robust models like Random forest/LGM/XGBoost will automatically handle missing values but not the target

# %%
OB_df = OB_df.dropna(subset=["transaction_amount"])

# %%
! pip install matplotlib
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/homebrew/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
grouped_company_customer = OB_df.groupby(["company_id", "customer_id"]).size()
grouped_company_customer.head()
# Out:
# company_id  customer_id
# company_1   102            5
#             103            2
#             104            3
#             106            1
#             107            1
# dtype: int64

# %%
from matplotlib import pyplot as plt

# Group by 'company_id' and count the number of rows in each group
grouped_company = OB_df.groupby("company_id").size()

# Plotting the distribution for each company_id
plt.figure(figsize=(10, 5))

grouped_company.plot(kind="bar")
plt.title("Number of Rows for Each Company ID")
plt.xlabel("Company ID")
plt.ylabel("Number of Rows")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
# We dont have a balance dataset, the company_3 has more samples than the other companies, which may cause the model to bias to it

# %%
for company_id in OB_df["company_id"].unique():
    grouped_company_customer = (
        OB_df[OB_df["company_id"] == company_id].groupby(["customer_id"]).size()
    )
    # Plotting the distribution for each [company_id, customer_id]
    # plt.subplots(i, 1)
    plt.figure(figsize=(10, 5))
    grouped_company_customer.plot(kind="bar")
    plt.title(f"{company_id}, Number of Rows for Each Customer ID")
    plt.xlabel("Customer ID")
    plt.ylabel("Number of Rows")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Observation
# None

# %%
OB_df["transaction_amount"].hist(figsize=(16, 20), bins=10, xlabelsize=6, ylabelsize=6);

# %%
! pip install seaborn
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/homebrew/lib/python3.8/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/homebrew/lib/python3.8/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/homebrew/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: zipp>=3.1.0 in /opt/homebrew/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.5 MB/s eta 0:00:007.8 MB/s eta 0:00:01
# Installing collected packages: seaborn
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

sns.boxplot(x=OB_df["transaction_amount"])
# Out:
# <Axes: xlabel='transaction_amount'>

# %%
def outlier_thresholds(dataframe, column, q1=0.25, q3=0.75):
    quartile1 = dataframe[column].quantile(q1)
    quartile3 = dataframe[column].quantile(q3)
    interquartile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquartile_range
    low_limit = quartile1 - 1.5 * interquartile_range
    return low_limit, up_limit


# Checking Outliers
def check_outlier(dataframe, column):
    low_limit, up_limit = outlier_thresholds(dataframe, column)
    outliers = (dataframe[column] > up_limit) | (dataframe[column] < low_limit)
    if outliers.any():
        return True
    else:
        return False


# Removing the outliers
def replace_with_thresholds(dataframe, column):
    low_limit, up_limit = outlier_thresholds(dataframe, column)
    dataframe.loc[(dataframe[column] < low_limit), column] = low_limit
    dataframe.loc[(dataframe[column] > up_limit), column] = up_limit

# %%
print("before outlier check", check_outlier(OB_df, "transaction_amount"))
replace_with_thresholds(OB_df, "transaction_amount")
print("after outlier check", check_outlier(OB_df, "transaction_amount"))
# Out:
# before outlier check True
# after outlier check False

# %% [markdown]
# ## Generate dummy numerical columns

# %%
OB_df = pd.get_dummies(
    OB_df, columns=["company_id", "transaction_description", "payment_method"]
)

# %%
boolean_columns = OB_df.select_dtypes(include=["bool"]).columns
OB_df[boolean_columns] = OB_df[boolean_columns].astype(int)
OB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 543 entries, 0 to 599
# Data columns (total 57 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   transaction_amount                                        543 non-null    float64
#  1   customer_id                                               543 non-null    int64
#  2   company_id_company_1                                      543 non-null    int64
#  3   company_id_company_2                                      543 non-null    int64
#  4   company_id_company_3                                      543 non-null    int64
#  5   company_id_company_4                                      543 non-null    int64
#  6   company_id_company_5                                      543 non-null    int64
#  7   transaction_description_Accessory revenue                 543 non-null    int64
#  8   transaction_description_Bed order                         543 non-null    int64
#  9   transaction_description_Beverage charge                   543 non-null    int64
#  10  transaction_description_Bicycle payment                   543 non-null    int64
#  11  transaction_description_Board game revenue                543 non-null    int64
#  12  transaction_description_Book transaction                  543 non-null    int64
#  13  transaction_description_Capital investment from investor  543 non-null    int64
#  14  transaction_description_Clothing charge                   543 non-null    int64
#  15  transaction_description_Credit card cashback              543 non-null    int64
#  16  transaction_description_Dairy product revenue             543 non-null    int64
#  17  transaction_description_Dining table revenue              543 non-null    int64
#  18  transaction_description_Educational toy income            543 non-null    int64
#  19  transaction_description_Employee travel expense           543 non-null    int64
#  20  transaction_description_Fitness accessory revenue         543 non-null    int64
#  21  transaction_description_Footwear income                   543 non-null    int64
#  22  transaction_description_Fresh produce transaction         543 non-null    int64
#  23  transaction_description_Furniture income                  543 non-null    int64
#  24  transaction_description_Groceries order                   543 non-null    int64
#  25  transaction_description_Gym equipment revenue             543 non-null    int64
#  26  transaction_description_Haircare payment                  543 non-null    int64
#  27  transaction_description_Health product order              543 non-null    int64
#  28  transaction_description_Kids clothing transaction         543 non-null    int64
#  29  transaction_description_Laptop payment                    543 non-null    int64
#  30  transaction_description_Loan received from bank           543 non-null    int64
#  31  transaction_description_Makeup transaction                543 non-null    int64
#  32  transaction_description_Marketing expense                 543 non-null    int64
#  33  transaction_description_Men's apparel payment             543 non-null    int64
#  34  transaction_description_Mobile phone transaction          543 non-null    int64
#  35  transaction_description_Notebook charge                   543 non-null    int64
#  36  transaction_description_Office chair income               543 non-null    int64
#  37  transaction_description_Office supplies purchase          543 non-null    int64
#  38  transaction_description_Operational expense               543 non-null    int64
#  39  transaction_description_Outdoor sports transaction        543 non-null    int64
#  40  transaction_description_Pen order                         543 non-null    int64
#  41  transaction_description_Puzzle charge                     543 non-null    int64
#  42  transaction_description_Rebate from supplier              543 non-null    int64
#  43  transaction_description_Refund processed                  543 non-null    int64
#  44  transaction_description_Skincare income                   543 non-null    int64
#  45  transaction_description_Snack payment                     543 non-null    int64
#  46  transaction_description_Stationery payment                543 non-null    int64
#  47  transaction_description_Supplements charge                543 non-null    int64
#  48  transaction_description_Tablet income                     543 non-null    int64
#  49  transaction_description_Toy payment                       543 non-null    int64
#  50  transaction_description_VAT refund                        543 non-null    int64
#  51  transaction_description_Video game order                  543 non-null    int64
#  52  transaction_description_Women's apparel order             543 non-null    int64
#  53  transaction_description_electronics transaction           543 non-null    int64
#  54  payment_method_credit_card                                543 non-null    int64
#  55  payment_method_debit_card                                 543 non-null    int64
#  56  payment_method_paypal                                     543 non-null    int64
# dtypes: float64(1), int64(56)
# memory usage: 246.0 KB

# %%
OB_df.to_csv("clean_revenue_data.csv", index=False)

# %%
OB_df.to_csv("with_outlier_revenue_data.csv", index=False)

# %% [markdown]
# # Observation
# this hist show that we have outliers, since most of the total_amount values are between -0.5 to 0.5, but we have few samples that have values out of range
# ## conclution
# It's not a good idea to fill the None values with the mean. since we have outliers in our data
